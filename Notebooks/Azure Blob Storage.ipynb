# %%
storage_account_name = ""
storage_account_key = ""
container = ""

spark.conf.set(f"fs.azure.account.key.{storage_account_name}.blob.core.windows.net", storage_account_key)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.fs.ls(f"wasbs://{container}@databricksdemostorage.blob.core.windows.net/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: [FileInfo(path=&#39;wasbs://input@databricksdemostorage.blob.core.windows.net/new/&#39;, name=&#39;new/&#39;, size=0),
#  FileInfo(path=&#39;wasbs://input@databricksdemostorage.blob.core.windows.net/pandas.csv&#39;, name=&#39;pandas.csv&#39;, size=199),
#  FileInfo(path=&#39;wasbs://input@databricksdemostorage.blob.core.windows.net/retrain_housing_data.csv&#39;, name=&#39;retrain_housing_data.csv&#39;, size=400)]</div>

# %%
# %fs ls wasbs://input@databricksdemostorage.blob.core.windows.net/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>wasbs://input@databricksdemostorage.blob.core.windows.net/retrain_housing_data.csv</td><td>retrain_housing_data.csv</td><td>400</td></tr></tbody></table></div>

# %%
df = spark.read \
  .option("header", "true") \
  .option("inferSchema", "true") \
  .option("delimiter", ",") \
  .csv(f"wasbs://{container}@{storage_account_name}.blob.core.windows.net/retrain_housing_data.csv")

df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+---------------+
# longitude|latitude|housing_median_age|total_rooms|total_bedrooms|population|households|median_income|median_house_value|ocean_proximity|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+---------------+
#   -122.29|   37.73|               8.0|     4004.0|        2281.0|    1300.0|      55.0|          4.4|            110500|         INLAND|
#   -120.72|   35.33|              11.0|     1602.0|         838.0|     148.0|     991.0|        2.433|             88320|       NEAR BAY|
#   -121.99|   36.42|              33.0|      258.0|          77.0|    2100.0|     279.0|         2.69|             92310|      &lt;1H OCEAN|
#   -119.88|    38.1|              18.0|     4911.0|         211.0|    1721.0|     375.0|        5.111|            202700|     NEAR OCEAN|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+---------------+
#
# </div>

# %%
dbutils.fs.mount(
  source = f"wasbs://{container}@{storage_account_name}.blob.core.windows.net",
  mount_point = "/mnt/azureStorage",
  extra_configs = {f"fs.azure.account.key.{storage_account_name}.blob.core.windows.net": storage_account_key}
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: True</div>

# %%
dbutils.fs.mounts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: [MountInfo(mountPoint=&#39;/databricks-datasets&#39;, source=&#39;databricks-datasets&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/azureStorage&#39;, source=&#39;wasbs://input@databricksdemostorage.blob.core.windows.net&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/adls&#39;, source=&#39;adl://databricksdls.azuredatalakestore.net/data&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/databricks/mlflow-tracking&#39;, source=&#39;databricks/mlflow-tracking&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/databricks-results&#39;, source=&#39;databricks-results&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/databricks/mlflow-registry&#39;, source=&#39;databricks/mlflow-registry&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/train&#39;, source=&#39;adl://dlsdemo2.azuredatalakestore.net/train&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/whales&#39;, source=&#39;adl://dlsdemo2.azuredatalakestore.net/train&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/audio&#39;, source=&#39;wasbs://audio@databricksdemostorage.blob.core.windows.net&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/adls-data&#39;, source=&#39;adl://databricksdls.azuredatalakestore.net/data&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/data&#39;, source=&#39;wasbs://data@databricksdemostorage.blob.core.windows.net&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/&#39;, source=&#39;DatabricksRoot&#39;, encryptionType=&#39;&#39;)]</div>

# %%
#dbutils.fs.unmount("/mnt/azureStorage")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/azureStorage has been unmounted.
# Out[6]: True</div>

# %%
# %fs ls "dbfs:/mnt/azureStorage"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/azureStorage/retrain_housing_data.csv</td><td>retrain_housing_data.csv</td><td>400</td></tr></tbody></table></div>

# %%
df2 = spark.read \
  .option("header", "true") \
  .option("inferSchema", "true") \
  .option("delimiter", ",") \
  .csv("/mnt/azureStorage/retrain_housing_data.csv")

df2.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+---------------+
# longitude|latitude|housing_median_age|total_rooms|total_bedrooms|population|households|median_income|median_house_value|ocean_proximity|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+---------------+
#   -122.29|   37.73|               8.0|     4004.0|        2281.0|    1300.0|      55.0|          4.4|            110500|         INLAND|
#   -120.72|   35.33|              11.0|     1602.0|         838.0|     148.0|     991.0|        2.433|             88320|       NEAR BAY|
#   -121.99|   36.42|              33.0|      258.0|          77.0|    2100.0|     279.0|         2.69|             92310|      &lt;1H OCEAN|
#   -119.88|    38.1|              18.0|     4911.0|         211.0|    1721.0|     375.0|        5.111|            202700|     NEAR OCEAN|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+---------------+
#
# </div>

# %%
data = spark.createDataFrame([(-114.42, 35.1, 11.0, 325.0, 94.0, 1212.0, 52.0, 5.22, 301500, "INLAND")], ["longitude", "latitude", "housing_median_age", "total_rooms", "total_bedrooms", "population", "households", "median_income", "median_house_value", "ocean_proximity"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+---------------+
# longitude|latitude|housing_median_age|total_rooms|total_bedrooms|population|households|median_income|median_house_value|ocean_proximity|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+---------------+
#   -114.42|    35.1|              11.0|      325.0|          94.0|    1212.0|      52.0|         5.22|            301500|         INLAND|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+---------------+
#
# </div>

# %%
data.write.csv(f"wasbs://{container}@{storage_account_name}.blob.core.windows.net/new")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.fs.ls(f"wasbs://{container}@{storage_account_name}.blob.core.windows.net/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: [FileInfo(path=&#39;wasbs://input@databricksdemostorage.blob.core.windows.net/new.csv/&#39;, name=&#39;new.csv/&#39;, size=0),
#  FileInfo(path=&#39;wasbs://input@databricksdemostorage.blob.core.windows.net/retrain_housing_data.csv&#39;, name=&#39;retrain_housing_data.csv&#39;, size=400)]</div>

# %%
pandas_df = data.toPandas()
pandas_df.to_csv("/dbfs/FileStore/tables/pandas.csv", encoding="UTF-8")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pandas_df.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[34]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>longitude</th>
#       <th>latitude</th>
#       <th>housing_median_age</th>
#       <th>total_rooms</th>
#       <th>total_bedrooms</th>
#       <th>population</th>
#       <th>households</th>
#       <th>median_income</th>
#       <th>median_house_value</th>
#       <th>ocean_proximity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-114.42</td>
#       <td>35.1</td>
#       <td>11.0</td>
#       <td>325.0</td>
#       <td>94.0</td>
#       <td>1212.0</td>
#       <td>52.0</td>
#       <td>5.22</td>
#       <td>301500</td>
#       <td>INLAND</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# %fs ls dbfs:/FileStore/tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/College.csv</td><td>College.csv</td><td>75702</td></tr><tr><td>dbfs:/FileStore/tables/Most_Recent_Cohorts_Scorecard_Elements-3e14e.csv</td><td>Most_Recent_Cohorts_Scorecard_Elements-3e14e.csv</td><td>4830464</td></tr><tr><td>dbfs:/FileStore/tables/Tweets.csv</td><td>Tweets.csv</td><td>244067</td></tr><tr><td>dbfs:/FileStore/tables/bank.csv</td><td>bank.csv</td><td>461474</td></tr><tr><td>dbfs:/FileStore/tables/pandas.csv</td><td>pandas.csv</td><td>199</td></tr><tr><td>dbfs:/FileStore/tables/test.csv</td><td>test.csv</td><td>28629</td></tr><tr><td>dbfs:/FileStore/tables/titanic.csv</td><td>titanic.csv</td><td>61194</td></tr></tbody></table></div>

# %%
dbutils.library.installPyPI("azure.storage.blob")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: True</div>

# %%
from azure.storage.blob import BlobClient
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
connection = ""
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
client = BlobClient.from_connection_string(connection, container_name="", blob_name="pandas.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
with open("/dbfs/FileStore/tables/pandas.csv", "rb") as f:
  client.upload_blob(f)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs ls wasbs://input@databricksdemostorage.blob.core.windows.net/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>wasbs://input@databricksdemostorage.blob.core.windows.net/new.csv/</td><td>new.csv/</td><td>0</td></tr><tr><td>wasbs://input@databricksdemostorage.blob.core.windows.net/pandas.csv</td><td>pandas.csv</td><td>199</td></tr><tr><td>wasbs://input@databricksdemostorage.blob.core.windows.net/retrain_housing_data.csv</td><td>retrain_housing_data.csv</td><td>400</td></tr></tbody></table></div>

# %%
new_data = client.download_blob()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
new_data.content_as_text()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[33]: &#39;,longitude,latitude,housing_median_age,total_rooms,total_bedrooms,population,households,median_income,median_house_value,ocean_proximity\n0,-114.42,35.1,11.0,325.0,94.0,1212.0,52.0,5.22,301500,INLAND\n&#39;</div>
